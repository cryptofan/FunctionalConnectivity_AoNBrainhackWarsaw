# %%
import numpy as np

# %%
# open the data:
datafolder = '/Users/nataliabielczyk/Desktop/Brainhack/PIPELINE/datasets/data_conversations/'
filename = datafolder + 'Con1bySPEAKER.txt'

# %%
a = open(filename, 'r')

# %%
b = a.readlines()

# %%
times = []
events = []
for ind in range(len(b)-3):
    split_string = b[ind+2].split("\t")
    times.append(split_string[0])
    events.append(split_string[1][:-2])

# %%
events
# Out:
# ['b,H 01',
#  'AdHosttWhenSpeaking,b,S-Leg t1 t2 t3',
#  'Adap/H,b,S-Leg',
#  'AdHosttWhenSpeaking,e,S-Leg t1 t2 t3',
#  'Adap/H,e,S-Leg',
#  'AdHosttWhenSpeaking,b,OM t1 t2 t3',
#  'Adap/H,b,OM',
#  'AdHosttWhenSpeaking,e,OM t1 t2 t3',
#  'Adap/H,e,OM',
#  'b,G 01',
#  'e,H 01',
#  'e,G 01',
#  'b,H 02',
#  'b,G 02',
#  'e,H 02',
#  'e,G 02',
#  'b,H 03',
#  'Adap/G,b,UM',
#  'Adap/G,e,UM',
#  'e,H 03',
#  'b,G 03',
#  'e,G 03',
#  'b,H 04',
#  'e,H 04',
#  'b,G 04',
#  'e,G 04',
#  'b,H 05',
#  'e,H 05',
#  'b,G 05',
#  'e,G 05',
#  'b,H 06',
#  'AdHosttWhenSpeaking,b,UM t8',
#  'Adap/H,b,UM',
#  'AdHosttWhenSpeaking,e,UM t8',
#  'Adap/H,e,UM',
#  'b,G 06',
#  'e,H 06',
#  'e,G 06',
#  'b,H 07',
#  'e,H 07',
#  'b,G 07',
#  'e,G 07',
#  'b,H 08',
#  'Adap/G,b,UM',
#  'Adap/G,e,UM',
#  'b,G 08',
#  'e,H 08',
#  'e,G 08',
#  'b,H 09',
#  'Adap/G,b,S-Head',
#  'Adap/G,e,S-Head',
#  'e,H 09',
#  'b,G 09',
#  'e,G 09',
#  'b,H 10',
#  'e,H 10',
#  'b,G 10',
#  'e,G 10',
#  'b,H 11',
# ...
